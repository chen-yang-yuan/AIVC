# %%
import pickle

# %%
merge_dict = {
    
    # T lineage
    "CD4+ Tfh cell": "CD4+ T cell",
    "CD4+ Treg cell": "CD4+ T cell",
    "CD4+ Tm cell": "CD4+ T cell",
    "CD8+ Tem cell": "CD8+ T cell",
    "CD8+ Tex cell": "CD8+ T cell",
    "Proliferative lymphoid cell": "T cell",  # proliferating T-lineage

    # B lineage
    "B cell": "B cell",
    "Plasma cell": "B cell",

    # Myeloid
    "Monocyte": "Myeloid cell",
    "Macrophage": "Myeloid cell",
    "Neutrophil": "Myeloid cell",

    # Dendritic cells
    "cDC1": "Dendritic cell",
    "cDC2": "Dendritic cell",
    "cDC3": "Dendritic cell",
    "pDC": "Dendritic cell",

    # Endothelial and lymphatic endothelial
    "CapECs": "Endothelial cell",
    "Alveolar capECs": "Endothelial cell",
    "ArtECs": "Endothelial cell",
    "EMT ECs": "Endothelial cell",
    "VenECs": "Endothelial cell",
    "LECs": "Lymphatic endothelial cell",

    # Fibroblasts / CAFs
    "myCAF": "Fibroblast (CAF)",
    "iCAF_1": "Fibroblast (CAF)",
    "iCAF_2": "Fibroblast (CAF)",
    "Cervical fibroblast": "Fibroblast (CAF)",

    # Other stromal
    "SMC": "Smooth muscle cell",
    "Pericyte": "Pericyte",
    "Mesothelial": "Mesothelial cell",

    # Tumor vs non-malignant epithelium
    "Tumor": "Malignant cell",
    "Luminal cell": "Epithelial cell (non-malignant)",
    "Luminal hormone-responsive": "Epithelial cell (non-malignant)",
    "Luminal secretory": "Epithelial cell (non-malignant)",
    "Basal cell": "Epithelial cell (non-malignant)",
    "Ciliated epithelial cell": "Epithelial cell (non-malignant)",
    "Glandular Epithelium": "Epithelial cell (non-malignant)",

    # Others
    "Mast cell": "Mast cell",
    "Fat cell": "Adipocyte"
}

# %%
with open("cell_type_dict.pkl", "wb") as f:
    pickle.dump(merge_dict, f)

# %%
manual_dict = {
    
    "Xenium_5K_LC": {"Adipocyte": [],
                    "B cell": ["12", "15"],
                    "CD4+ T cell": ["1"],
                    "CD8+ T cell": ["7", "30", "32"],
                    "Dendritic cell": ["2"],
                    "Endothelial cell": ["3", "13", "22", "25"],
                    "Epithelial cell (non-malignant)": ["19", "20", "23", "26", "28"],
                    "Fibroblast (CAF)": ["4", "10", "17"],
                    "Lymphatic endothelial cell": [],
                    "Malignant cell": ["8", "9", "11", "14", "31"],
                    "Mast cell": ["27"],
                    "Mesothelial cell": ["18"],
                    "Myeloid cell": ["6", "16"],
                    "Pericyte": ["24"],
                    "Smooth muscle cell": ["5"],
                    "T cell": [],
                    "Mixed": ["21"],
                    "Unknown": ["29", "33"]},
    
    "Xenium_5K_Prostate": {"Adipocyte": [],
                    "B cell": [],
                    "CD4+ T cell": [],
                    "CD8+ T cell": ["15"],
                    "Dendritic cell": [],
                    "Endothelial cell": ["10"],
                    "Epithelial cell (non-malignant)": [],
                    "Fibroblast (CAF)": ["6", "12"],
                    "Lymphatic endothelial cell": [],
                    "Malignant cell": ["2", "4", "5", "7", "9", "11", "13", "14"],
                    "Mast cell": ["18", "20"],
                    "Mesothelial cell": [],
                    "Myeloid cell": ["16", "19"],
                    "Pericyte": ["17"],
                    "Smooth muscle cell": ["3", "8"],
                    "T cell": [],
                    "Mixed": [],
                    "Unknown": ["1", "21", "22"]},
    
    "Xenium_5K_Skin": {"Adipocyte": [],
                    "B cell": ["12"],
                    "CD4+ T cell": [],
                    "CD8+ T cell": ["3", "13", "21", "24"],
                    "Dendritic cell": [],
                    "Endothelial cell": ["19"],
                    "Epithelial cell (non-malignant)": [],
                    "Fibroblast (CAF)": ["8", "17"],
                    "Lymphatic endothelial cell": [],
                    "Malignant cell": ["1", "2", "5", "6", "10", "11", "20", "26", "27", "28"],
                    "Mast cell": ["29"],
                    "Mesothelial cell": [],
                    "Myeloid cell": ["4", "7", "18"],
                    "Pericyte": ["14"],
                    "Smooth muscle cell": [],
                    "T cell": [],
                    "Mixed": ["9", "15", "22", "23", "25"],
                    "Unknown": ["16", "30"]}
}

# %%
with open("cell_type_dict_manual.pkl", "wb") as f:
    pickle.dump(manual_dict, f)
